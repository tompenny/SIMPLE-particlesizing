# %%
import cv2
import numpy as np

# Read image
img = cv2.imread('C:\\Users\\Tom\\Documents\\Yale\\Particle Sizing\\Focus One (Big spheres)\\1.jpg', cv2.IMREAD_GRAYSCALE)

# Convert to grayscale.
#gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Blur using 3 * 3 kernel.
gray_blurred = cv2.blur(img, (3, 3))

# Apply Hough transform on the blurred image.
detected_circles = cv2.HoughCircles(gray_blurred, cv2.HOUGH_GRADIENT, 1, 8, param1 = 50, param2 = 30, minRadius = 1, maxRadius = 70)

# %%
import matplotlib.pyplot as plt

figure, axes = plt.subplots()  
axes.imshow(img)
axes.set_aspect( 1 )
for i in detected_circles[0]:
    cc = plt.Circle((i[0], i[1]), i[2], fill = 0, color = 'r')
    axes.add_artist( cc ) 
#plt.show()

# %%
hist1 = np.histogram(np.transpose(detected_circles[0])[2], bins = 20, range = (0, 40))

# %%
# Read image
img = cv2.imread('C:\\Users\\Tom\\Documents\\Yale\\Particle Sizing\\Focus Two\\1.jpg', cv2.IMREAD_GRAYSCALE)

# Convert to grayscale.
#gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Blur using 3 * 3 kernel.
gray_blurred = cv2.blur(img, (3, 3))

# Apply Hough transform on the blurred image.
detected_circles = cv2.HoughCircles(gray_blurred, cv2.HOUGH_GRADIENT, 1, 8, param1 = 50, param2 = 32, minRadius = 1, maxRadius = 70)

# %%
figure, axes = plt.subplots()  
axes.imshow(img)
axes.set_aspect( 1 )
for i in detected_circles[0]:
    cc = plt.Circle((i[0], i[1]), i[2], fill = 0, color = 'r')
    axes.add_artist( cc ) 
#plt.show()

# %%
hist2 = np.histogram(np.transpose(detected_circles[0])[2], bins = 20, range = (0, 40))

# %%
# Read image
img = cv2.imread('C:\\Users\\Tom\\Documents\\Yale\\Particle Sizing\\Focus Three\\1.jpg', cv2.IMREAD_GRAYSCALE)

# Convert to grayscale.
#gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Blur using 3 * 3 kernel.
gray_blurred = cv2.blur(img, (3, 3))

# Apply Hough transform on the blurred image.
detected_circles = cv2.HoughCircles(gray_blurred, cv2.HOUGH_GRADIENT, 1, 8, param1 = 50, param2 = 32, minRadius = 1, maxRadius = 70)

# %%
figure, axes = plt.subplots()  
axes.imshow(img)
axes.set_aspect( 1 )
for i in detected_circles[0]:
    cc = plt.Circle((i[0], i[1]), i[2], fill = 0, color = 'r')
    axes.add_artist( cc ) 
#plt.show()

# %%
hist3 = np.histogram(np.transpose(detected_circles[0])[2], bins = 20, range = (0, 40))

# %%
plt.plot(hist1[1][1:], hist1[0])
plt.plot(hist2[1][1:], hist2[0])
plt.plot(hist2[1][1:], hist3[0])

# %%
# Focus Three kind of looks best - it still sees big ones but can also see small

# %%
detected_radii = np.array([])
for i in range(1, 31):
    img = cv2.imread('C:\\Users\\Tom\\Documents\\Yale\\Particle Sizing\\Focus Three\\' + str(i) + '.jpg', cv2.IMREAD_GRAYSCALE)
    gray_blurred = cv2.blur(img, (3, 3))
    detected_circles = cv2.HoughCircles(gray_blurred, cv2.HOUGH_GRADIENT, 1, 8, param1 = 50, param2 = 32, minRadius = 1, maxRadius = 70)
    #print(detected_circles)
    detected_radii = np.concatenate((detected_radii, np.transpose(detected_circles[0])[2]))

# %%
hist = np.histogram(detected_radii, bins = 40, range = (0, 40))

# %%
plt.hist(detected_radii, bins = 30, range = (0, 40))
# Out:
# (array([ 0.,  0.,  0.,  0.,  0.,  5., 15., 31., 35., 38., 45., 54., 48.,
#         50., 45., 65., 47., 47., 51., 57., 59., 47., 29., 11.,  0.,  0.,
#          0.,  0.,  0.,  0.]),
#  array([ 0.        ,  1.33333333,  2.66666667,  4.        ,  5.33333333,
#          6.66666667,  8.        ,  9.33333333, 10.66666667, 12.        ,
#         13.33333333, 14.66666667, 16.        , 17.33333333, 18.66666667,
#         20.        , 21.33333333, 22.66666667, 24.        , 25.33333333,
#         26.66666667, 28.        , 29.33333333, 30.66666667, 32.        ,
#         33.33333333, 34.66666667, 36.        , 37.33333333, 38.66666667,
#         40.        ]),
#  <BarContainer object of 30 artists>)

# %%
img = cv2.imread('C:\\Users\\Tom\\Documents\\Yale\\Particle Sizing\\Focus Three\\calibration.jpg', cv2.IMREAD_GRAYSCALE)

gray = img
edges = cv2.Canny(gray,50,150,apertureSize = 3)
#cv2.imwrite('edges-50-150.jpg',edges)
minLineLength=200
lines = cv2.HoughLinesP(image=edges,rho=1,theta=np.pi/500, threshold=100,lines=np.array([]), minLineLength=minLineLength,maxLineGap=200)

# %%
plt.figure(figsize = (20, 20))
plt.imshow(img)
for i in range(len(lines)):
    plt.plot([lines[i][0][0], lines[i][0][2]], [lines[i][0][1], lines[i][0][3]], 'r', linewidth = 0.8)

# %%
avrx = []
for i in lines:
    i[0][0] +
# Out:
# array([[[463, 865, 463, 544]],
#
#        [[386, 738, 386, 496]],
#
#        [[590, 783, 590, 576]],
#
#        [[378, 735, 378, 488]],
#
#        [[707, 559, 707, 360]],
#
#        [[530, 654, 530, 488]],
#
#        [[505, 663, 505, 488]],
#
#        [[715, 535, 715, 369]],
#
#        [[455, 839, 455, 639]],
#
#        [[514, 735, 514, 553]],
#
#        [[580, 486, 580, 232]],
#
#        [[588, 502, 588, 327]],
#
#        [[453, 614, 453, 361]],
#
#        [[581, 663, 581, 443]],
#
#        [[462, 593, 462, 440]],
#
#        [[683, 728, 683, 486]],
#
#        [[582, 778, 582, 608]],
#
#        [[454, 686, 454, 472]],
#
#        [[818, 735, 818, 560]],
#
#        [[564, 738, 564, 511]],
#
#        [[615, 737, 615, 583]],
#
#        [[861, 711, 861, 584]],
#
#        [[742, 736, 742, 576]],
#
#        [[716, 662, 716, 530]],
#
#        [[657, 616, 657, 487]],
#
#        [[591, 993, 591, 769]],
#
#        [[606, 622, 606, 488]],
#
#        [[767, 736, 767, 521]],
#
# ...

# %%
lines[0][0]
# Out:
# array([580, 232, 584, 966], dtype=int32)
